# %% [markdown]
# # Matplotlib & Week 1 Mini-Notebook
# ## Learning Objectives
# * Create labeled line, scatter, bar, and histogram plots.
#
# * Combine multiple plots into one figure using subplots.
#
# * Assemble a complete mini-notebook using NumPy, Pandas, and Matplotlib together.
#
# ## Key Topics
# * Why visualization matters for exploration and communication
#
# * Matplotlib basics: plot, labels, title, show
#
# * The four core plot types: line, scatter, bar, histogram
#
# * Subplots for side-by-side comparison
#
# * Assembling a load → process → visualize notebook
#
# ## Lesson Content
# ### 5.1 Why Visualization Matters
# Numbers in a table hide patterns that a chart reveals instantly — trends, clusters, outliers, and relationships between variables. Visualization is both an exploration tool (understanding data during analysis) and a communication tool (explaining findings to others), and it is the foundation of the Exploratory Data Analysis (EDA) work in Week 2.
#
# ### 5.2 The Matplotlib Basics
# Matplotlib is the core plotting library. The standard workflow: import pyplot, call a plotting function, add labels and a title, then show. Every plot should always be labeled — an unlabeled chart is not a finding, it's a puzzle.

# %%
import matplotlib.pyplot as plt
import pandas as pd
x = [0.8,0.9,0.921,0.987,0.56,.89,.19,.47,.23,.62]
y   =[0.89,0.99,1,1.3,0.63,.93,.2,.78,.33,.72]
plt.plot(x, y)
plt.xlabel("Time")
plt.ylabel("Value")
plt.title("Value over Time")
plt.show()

# %% [markdown]
# ### 5.3 The Four Core Plot Types
#
# * Line->plt.plot():	A trend or change over a continuous axis (e.g. time)
# * Scatter->	plt.scatter()	:The relationship between two numeric variables
# * Bar->	plt.bar()	:Comparison of a value across categories
# * Histogram->	 plt.hist()	:The distribution (shape/spread) of a single variable
# ### 5.4 Subplots
# Subplots place multiple charts in one figure for side-by-side comparison, using plt.subplots() to create a grid of axes. This is essential for EDA, where you often want to see several variables' distributions at once.

# %%
df = pd.read_csv("StudentsPerformance.csv")

fig, axes = plt.subplots(1, 2, figsize=(10, 4))
axes[0].hist(df["math score"])
axes[0].set_title("Math score distribution")
axes[1].scatter(df["math score"], df["reading score"])
axes[1].set_title("Math vs. Reading score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5.5 Bringing It Together
# Week 1 closes with a single mini-notebook that uses all four libraries in sequence: NumPy for a computation, Pandas to load and clean a dataset, and Matplotlib to visualize it — the exact pipeline shape (load → process → visualize) that every project in this program follows.

# %% [markdown]
# ### Hands-On Lab: Week 1 Integrated Mini-Notebook
# #### Step 1: Load and clean a provided dataset with Pandas (handling any missing values)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the Students Performance dataset
df = pd.read_csv("StudentsPerformance.csv")

# Display first few rows
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
# Clean data - drop any rows with missing values (though none exist)
df = df.dropna()

# %% [markdown]
# #### Step 2: Use NumPy to compute at least one derived numeric feature or summary statistic.

# %%
mean_reading_score=np.mean(df["reading score"])
print(mean_reading_score)
# Out:
# 69.169

# %%
print(np.max(df["math score"]))
# Out:
# 100

# %% [markdown]
# #### Step 3: Step 3: Produce at least three labeled plots (including a histogram and a scatter plot) exploring the data.
# Plot 1:

# %%
plt.figure(figsize=(10, 6))
plt.hist(df["math score"], bins=20, color='skyblue')
plt.xlabel("Math Score")
plt.ylabel("Frequency")
plt.title("Distribution of Math Scores")
# Out:
# Text(0.5, 1.0, 'Distribution of Math Scores')

# %% [markdown]
# Plot 2:

# %%
plt.figure(figsize=(10, 6))
plt.hist(df["reading score"], bins=20)
plt.xlabel("Reading Score")
plt.ylabel("Frequency")
plt.title("Distribution of Reading Scores")
# Out:
# Text(0.5, 1.0, 'Distribution of Reading Scores')

# %% [markdown]
# Plot 3: Scatter Plot

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df["math score"], df["reading score"])
plt.xlabel("Math Score")
plt.ylabel("Reading Score")
plt.title("Relationship Between Math and Reading Scores")
# Out:
# Text(0.5, 1.0, 'Relationship Between Math and Reading Scores')

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df["reading score"], df["writing score"])
plt.xlabel("reading score")
plt.ylabel("writing score")
plt.title("Relationship Between reading Score and writing Score")
# Out:
# Text(0.5, 1.0, 'Relationship Between reading Score and writing Score')

# %% [markdown]
# plot4: bar plot

# %%
plt.figure(figsize=(10, 4))
plt.bar(df["reading score"], df["math score"])
plt.xlabel("reading score")
plt.ylabel("math score")
plt.title("Relationship Between reading Score and math Score")
# Out:
# Text(0.5, 1.0, 'Relationship Between reading Score and math Score')

# %% [markdown]
# ## Visualization Insights
# * Line Plot
# The line chart indicates the sepal length flux with the data. Now you can see how the measurement has changed over the sample.
#
# * Scatter Plot
# The scatter plot depicts the sepal length against the petal length. Shall we look for some patterns or correlations in these two numbers?
#
# * Histogram
# This is a histogram of the sepal length. When you want to get a sense of the distribution of your data, or how frequently certain values occur, it’s very useful.
#
# * Bar Plot
# The bar plot gives the number of samples per species. It is the distribution of types of categorical variables within the data.

# %% [markdown]
# #### Tools Used
# Matplotlib  •  Pandas  •  NumPy  •  Jupyter Notebook  •  Git & GitHub

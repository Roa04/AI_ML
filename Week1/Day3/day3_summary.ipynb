# %% [markdown]
# ### What it covers
#
# - NumPy purpose and why it is important for data science
# - Creating arrays from lists and with helper functions
#   - `np.array`
#   - `np.zeros`
#   - `np.ones`
#   - `np.eye`
#   - `np.arange`
#   - `np.random.rand`
#   - `np.linspace`
# - Inspecting array metadata
#   - `shape`
#   - `dtype`
#   - `ndim`
#   - `size`
#   - `itemsize`
#   - `nbytes`
# - Indexing and slicing arrays
#   - 1D and 2D access
#   - row/column selection
#   - slicing examples
# - Vectorized operations
#   - elementwise multiplication and addition
#   - using `.mean()`
#   - boolean masking
# - Broadcasting
#   - adding a row vector to a matrix
#   - combining arrays of compatible shapes

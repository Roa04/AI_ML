# %% [markdown]
# # Day 1 Summary — 26/7/2026
# ## Environment Setup & Jupyter Workflow
# This notebook summarizes everything I learned and did today.

# %% [markdown]
# ---
# ## 1. Checking Python & pip
# First, I checked that Python and pip were already installed on my computer using Command Prompt (cmd).
#
# Commands used (in Command Prompt, not here):
# ```
# python --version
# pip --version
# ```

# %% [markdown]
# ## 2. Creating a Project Folder
# Created a dedicated folder for this project.
#
# Commands used:
# ```
# cd Desktop
# mkdir Day1
# cd Day1
# ```
# ```
# C:\Users\ASUS>cd Desktop
# C:\Users\ASUS\Desktop>mkdir day1-project
# C:\Users\ASUS\Desktop>cd day1-project
# ```

# %% [markdown]
# ## 3. Virtual Environment |(venv)
# Created an isolated virtual environment so this project's packages don't conflict with other projects. Then activated it.
#
#
# Commands used:
# ```
# python -m venv .venv
# .venv\Scripts\activate
# ```
# ```
# C:\Users\ASUS\Desktop\AI_ML>python -m venv .venv
# C:\Users\ASUS\Desktop\AI_ML>.venv\Scripts\activate
# ```
# Note: When active, you see `(.venv)` at the start of the line.

# %% [markdown]
# ## 4. Installing Libraries
# Installed the main libraries needed for data science work.
#
# Command used:
# ```
# pip install numpy pandas matplotlib jupyter   # inside (.venv)
# ```
# ```
# (.venv) C:\Users\ASUS\Desktop\AI_ML>pip install numpy pandas matplotlib jupyter
# ```
# Notes:
# - numpy: for numbers and math
# - pandas: for tables and data
# - matplotlib: for charts and graphs
# - jupyter: the interactive notebook

# %% [markdown]
# ## 5. Saving requirements.txt
# Saved the exact versions of installed libraries into a file, so anyone can recreate the same environment.
#
# Command used:
# ```
# pip freeze > requirements.txt
# ```
# ```
# (.venv) C:\Users\ASUS\Desktop\AI_ML>pip freeze > requirements.txt
# ```

# %% [markdown]
# ## 6. Opening Jupyter Notebook
# Opened Jupyter Notebook in the browser to start working interactively.
#
# Command used:
# ```
# jupyter notebook
# ```
# ```
# (.venv) C:\Users\ASUS\Desktop\AI_ML>jupyter notebook
# ```

# %% [markdown]
# ## 7. Notebook Cells: Code vs Markdown
# A notebook is made of cells:
# 1. **Code cells**: run Python and show output directly below
# 2. **Markdown cells**: hold explanations/text, not code
#
# Note: Press `Shift + Enter` to run a cell and move to the next one.

# %%
# Testing that the libraries work
import numpy
import pandas
import matplotlib

print("numpy:", numpy.__version__)
print("pandas:", pandas.__version__)
print("matplotlib:", matplotlib.__version__)
# Out:
# numpy: 2.5.1
# pandas: 3.0.5
# matplotlib: 3.11.1

# %% [markdown]
# Expected output (from Day1_Environment_setup.ipynb, matches requirements.txt):
# ```
# numpy: 2.5.1
# pandas: 3.0.5
# matplotlib: 3.11.1
# ```

# %% [markdown]
# ## 8. Git Basics
# Git is used to save "snapshots" of my project so I can track changes and back up my work.
#
#
# Commands used:
# ```
# git init
# git add .
# git commit -m "Day1: Environment Setup"
# ```
# ```
#  C:\Users\ASUS\Desktop\AI_ML> cd Week1
#  C:\Users\ASUS\Desktop\AI_ML\Week1> git init
# C:\Users\ASUS\Desktop\AI_ML\Week1> git add .
# C:\Users\ASUS\Desktop\AI_ML\Week1> git commit -m "Day1: Environment Setup"
# ```
# - `git init`: start tracking this folder
# - `git add .`: stage all files (`.` means all files)
# - `git commit -m`: save a snapshot with a message

# %%
# Day 1 complete!
print("Day 1 complete: environment ready, notebook workflow understood, git initialized.")
# Out:
# Day 1 complete: environment ready, notebook workflow understood, git initialized.
